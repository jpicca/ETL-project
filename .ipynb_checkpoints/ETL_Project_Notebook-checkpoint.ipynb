# %%
import pandas as pd
from sqlalchemy import create_engine

# %%
patient_csv = "patient.csv"
patient_df = pd.read_csv(patient_csv)

route_csv = "route.csv"
route_df =pd.read_csv(route_csv)

# %%
rds_connection_string = "postgres:postgres@localhost:5432/ELT_Project"
engine = create_engine(f'postgresql://{rds_connection_string}')

# %%
engine.table_names()
# Out:
# ['patient', 'route']

# %%
patient_df.to_sql(name='patient', con=engine, if_exists='append', index=False)

# %%
route_df.to_sql(name='route', con=engine, if_exists='append', index=False)

# %%
Aggregate_df = pd.read_sql_query('select * from patient A LEFT JOIN route B ON A.patient_id = B.patient_id', con=engine)

Aggregate_df
# Out:
#       patient_id     sex  birth_year country               region group  \
# 0              1  female      1984.0   China  filtered at airport  None
# 1              1  female      1984.0   China  filtered at airport  None
# 2              2    male      1964.0   Korea  filtered at airport  None
# 3              2    male      1964.0   Korea  filtered at airport  None
# 4              3    male      1966.0   Korea         capital area  None
# ...          ...     ...         ...     ...                  ...   ...
# 4860        2795    None         NaN   Korea                 None  None
# 4861        3328    None         NaN   Korea                 None  None
# 4862        2502    None         NaN   Korea                 None  None
# 4863        2824    None         NaN   Korea                 None  None
# 4864        4237    None         NaN   Korea                 None  None
#
#      infection_reason infection_order  infected_by  contact_number  ...  \
# 0      visit to Wuhan             1.0          NaN            45.0  ...
# 1      visit to Wuhan             1.0          NaN            45.0  ...
# 2      visit to Wuhan             1.0          NaN            75.0  ...
# 3      visit to Wuhan             1.0          NaN            75.0  ...
# 4      visit to Wuhan             1.0          NaN            16.0  ...
# ...               ...             ...          ...             ...  ...
# 4860             None             NaN          NaN             NaN  ...
# 4861             None             NaN          NaN             NaN  ...
# 4862             None             NaN          NaN             NaN  ...
# 4863             None             NaN          NaN             NaN  ...
# 4864             None             NaN          NaN             NaN  ...
#
#                    region group infection_reason infection_order  infected_by  \
# 0     filtered at airport   0.0   visit to Wuhan             1.0          0.0
# 1     filtered at airport   0.0   visit to Wuhan             1.0          0.0
# 2     filtered at airport   0.0   visit to Wuhan             1.0          0.0
# 3     filtered at airport   0.0   visit to Wuhan             1.0          0.0
# 4            capital area   0.0   visit to Wuhan             1.0          0.0
# ...                   ...   ...              ...             ...          ...
# 4860                 None   NaN             None             NaN          NaN
# 4861                 None   NaN             None             NaN          NaN
# 4862                 None   NaN             None             NaN          NaN
# 4863                 None   NaN             None             NaN          NaN
# 4864                 None   NaN             None             NaN          NaN
#
#       contact_number confirmed_date released_date deceased_date     state
# 0               45.0     2020-01-20    2020-02-06          None  released
# 1               45.0     2020-01-20    2020-02-06          None  released
# 2               75.0     2020-01-24    2020-02-05          None  released
# 3               75.0     2020-01-24    2020-02-05          None  released
# 4               16.0     2020-01-26    2020-02-12          None  released
# ...              ...            ...           ...           ...       ...
# 4860             NaN           None          None          None      None
# 4861             NaN           None          None          None      None
# 4862             NaN           None          None          None      None
# 4863             NaN           None          None          None      None
# 4864             NaN           None          None          None      None
#
# [4865 rows x 35 columns]
